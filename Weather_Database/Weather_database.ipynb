# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
 #Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | nemuro
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | yerbogachen
# Processing Record 6 of Set 1 | merauke
# Processing Record 7 of Set 1 | narasannapeta
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | lampang
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | santa isabel do rio negro
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | temnikov
# Processing Record 14 of Set 1 | prince george
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | alofi
# Processing Record 19 of Set 1 | morondava
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 1 | krasnoselkup
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | norman wells
# Processing Record 26 of Set 1 | yazykovo
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | vila velha
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | aleksandrov gay
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | mount gambier
# Processing Record 37 of Set 1 | vila franca do campo
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | juegang
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | nuuk
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | trinidad
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | palembang
# Processing Record 4 of Set 2 | senador jose porfirio
# Processing Record 5 of Set 2 | cayenne
# Processing Record 6 of Set 2 | lata
# Processing Record 7 of Set 2 | hurghada
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | praia da vitoria
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | tignere
# Processing Record 13 of Set 2 | anadyr
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | yaring
# Processing Record 17 of Set 2 | talnakh
# Processing Record 18 of Set 2 | inta
# Processing Record 19 of Set 2 | acajutla
# Processing Record 20 of Set 2 | aklavik
# Processing Record 21 of Set 2 | cockburn town
# Processing Record 22 of Set 2 | guerrero negro
# Processing Record 23 of Set 2 | tangzhai
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | zhangjiakou
# Processing Record 27 of Set 2 | tuatapere
# Processing Record 28 of Set 2 | sept-iles
# Processing Record 29 of Set 2 | shingu
# Processing Record 30 of Set 2 | turinsk
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | uruguaiana
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | san policarpo
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | dhadar
# Processing Record 39 of Set 2 | aloleng
# Processing Record 40 of Set 2 | verkhoyansk
# Processing Record 41 of Set 2 | paraiso
# Processing Record 42 of Set 2 | linxia
# Processing Record 43 of Set 2 | havre-saint-pierre
# Processing Record 44 of Set 2 | rio grande city
# Processing Record 45 of Set 2 | valavanur
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | ballina
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | gbadolite
# Processing Record 50 of Set 2 | rock sound
# Processing Record 1 of Set 3 | sioux lookout
# Processing Record 2 of Set 3 | jawhar
# Processing Record 3 of Set 3 | hailey
# Processing Record 4 of Set 3 | codajas
# Processing Record 5 of Set 3 | yala
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | sao filipe
# Processing Record 10 of Set 3 | baruun-urt
# Processing Record 11 of Set 3 | selu
# Processing Record 12 of Set 3 | iskar
# Processing Record 13 of Set 3 | komsomolskiy
# Processing Record 14 of Set 3 | susanino
# Processing Record 15 of Set 3 | chiredzi
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | qaanaaq
# Processing Record 18 of Set 3 | batemans bay
# Processing Record 19 of Set 3 | walvis bay
# Processing Record 20 of Set 3 | jinxiang
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | kamogawa
# Processing Record 23 of Set 3 | port hedland
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | darnah
# Processing Record 26 of Set 3 | lang son
# Processing Record 27 of Set 3 | mango
# Processing Record 28 of Set 3 | tashtagol
# Processing Record 29 of Set 3 | lazaro cardenas
# Processing Record 30 of Set 3 | santa maria
# Processing Record 31 of Set 3 | bilma
# Processing Record 32 of Set 3 | nishihara
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | lavrentiya
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | atocha
# Processing Record 37 of Set 3 | gander
# Processing Record 38 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 3 | aksu
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | de aar
# Processing Record 45 of Set 3 | havelock
# Processing Record 46 of Set 3 | namibe
# Processing Record 47 of Set 3 | insar
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | prainha
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | bulgan
# Processing Record 2 of Set 4 | mokhsogollokh
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | karpuninskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | el higo
# Processing Record 6 of Set 4 | tadine
# Processing Record 7 of Set 4 | antalaha
# Processing Record 8 of Set 4 | cap malheureux
# Processing Record 9 of Set 4 | gurupi
# Processing Record 10 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | mongo
# Processing Record 13 of Set 4 | tommot
# Processing Record 14 of Set 4 | hof
# Processing Record 15 of Set 4 | karratha
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | san ignacio
# Processing Record 18 of Set 4 | matagami
# Processing Record 19 of Set 4 | atar
# Processing Record 20 of Set 4 | rodrigues alves
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | rutul
# Processing Record 24 of Set 4 | rovnoye
# Processing Record 25 of Set 4 | itoman
# Processing Record 26 of Set 4 | galle
# Processing Record 27 of Set 4 | katsuura
# Processing Record 28 of Set 4 | toktogul
# Processing Record 29 of Set 4 | algiers
# Processing Record 30 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | vikarabad
# Processing Record 33 of Set 4 | severnyy
# Processing Record 34 of Set 4 | at-bashi
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | dudinka
# Processing Record 37 of Set 4 | markala
# Processing Record 38 of Set 4 | panguna
# Processing Record 39 of Set 4 | tautira
# Processing Record 40 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | soe
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | tecoanapa
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | damnagar
# Processing Record 48 of Set 4 | dawlatabad
# Processing Record 49 of Set 4 | srednebelaya
# Processing Record 50 of Set 4 | mahebourg
# Processing Record 1 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 5 | el campo
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | marrakesh
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | canavieiras
# Processing Record 7 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 5 | karla
# Processing Record 9 of Set 5 | pinega
# Processing Record 10 of Set 5 | coihaique
# Processing Record 11 of Set 5 | broome
# Processing Record 12 of Set 5 | high rock
# Processing Record 13 of Set 5 | snezhnogorsk
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | atbasar
# Processing Record 16 of Set 5 | christchurch
# Processing Record 17 of Set 5 | sao joao da barra
# Processing Record 18 of Set 5 | paris
# Processing Record 19 of Set 5 | wenatchee
# Processing Record 20 of Set 5 | santa marta
# Processing Record 21 of Set 5 | teya
# Processing Record 22 of Set 5 | kungurtug
# Processing Record 23 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 5 | zyryanka
# Processing Record 25 of Set 5 | mamit
# Processing Record 26 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | berlevag
# Processing Record 29 of Set 5 | skibbereen
# Processing Record 30 of Set 5 | bonthe
# Processing Record 31 of Set 5 | northam
# Processing Record 32 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 5 | zima
# Processing Record 34 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 35 of Set 5 | korla
# Processing Record 36 of Set 5 | coquimbo
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | nanortalik
# Processing Record 39 of Set 5 | zhigansk
# Processing Record 40 of Set 5 | brigantine
# Processing Record 41 of Set 5 | avarua
# Processing Record 42 of Set 5 | isangel
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | bud
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | port lincoln
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | raudeberg
# Processing Record 49 of Set 5 | hanna
# Processing Record 50 of Set 5 | namatanai
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 6 | fare
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | maraa
# Processing Record 6 of Set 6 | mareeba
# Processing Record 7 of Set 6 | muros
# Processing Record 8 of Set 6 | kibala
# Processing Record 9 of Set 6 | nenagh
# Processing Record 10 of Set 6 | kilindoni
# Processing Record 11 of Set 6 | lompoc
# Processing Record 12 of Set 6 | mpanda
# Processing Record 13 of Set 6 | esmeralda
# Processing Record 14 of Set 6 | basoko
# Processing Record 15 of Set 6 | kloulklubed
# Processing Record 16 of Set 6 | lagoa
# Processing Record 17 of Set 6 | nokaneng
# Processing Record 18 of Set 6 | solnechnyy
# Processing Record 19 of Set 6 | longyan
# Processing Record 20 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 6 | ust-kuyga
# Processing Record 22 of Set 6 | port macquarie
# Processing Record 23 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 6 | mangochi
# Processing Record 25 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 6 | kununurra
# Processing Record 27 of Set 6 | torbay
# Processing Record 28 of Set 6 | grindavik
# Processing Record 29 of Set 6 | leningradskiy
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | bin qirdan
# Processing Record 32 of Set 6 | kjollefjord
# Processing Record 33 of Set 6 | salinopolis
# Processing Record 34 of Set 6 | mocuba
# Processing Record 35 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 6 | albufeira
# Processing Record 37 of Set 6 | durango
# Processing Record 38 of Set 6 | kalmunai
# Processing Record 39 of Set 6 | wasilla
# Processing Record 40 of Set 6 | itupiranga
# Processing Record 41 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 6 | bangkok
# Processing Record 43 of Set 6 | torbat-e jam
# Processing Record 44 of Set 6 | bundaberg
# Processing Record 45 of Set 6 | ust-koksa
# Processing Record 46 of Set 6 | morehead
# Processing Record 47 of Set 6 | half moon bay
# Processing Record 48 of Set 6 | taber
# Processing Record 49 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | verkhnyaya inta
# Processing Record 2 of Set 7 | handan
# Processing Record 3 of Set 7 | kalispell
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | hammerfest
# Processing Record 6 of Set 7 | sorland
# Processing Record 7 of Set 7 | ahipara
# Processing Record 8 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 7 | bom jesus
# Processing Record 10 of Set 7 | great falls
# Processing Record 11 of Set 7 | alindao
# Processing Record 12 of Set 7 | jaca
# Processing Record 13 of Set 7 | richards bay
# Processing Record 14 of Set 7 | hithadhoo
# Processing Record 15 of Set 7 | qorveh
# Processing Record 16 of Set 7 | matay
# Processing Record 17 of Set 7 | sokoni
# Processing Record 18 of Set 7 | anzio
# Processing Record 19 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 7 | malindi
# Processing Record 21 of Set 7 | svetlogorsk
# Processing Record 22 of Set 7 | birin
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | fairbanks
# Processing Record 25 of Set 7 | itarema
# Processing Record 26 of Set 7 | forestville
# Processing Record 27 of Set 7 | clayton
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | daokou
# Processing Record 30 of Set 7 | yangambi
# Processing Record 31 of Set 7 | galesong
# Processing Record 32 of Set 7 | niquero
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | yatou
# Processing Record 35 of Set 7 | srostki
# Processing Record 36 of Set 7 | baoding
# Processing Record 37 of Set 7 | moa
# Processing Record 38 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 7 | itanhaem
# Processing Record 40 of Set 7 | naze
# Processing Record 41 of Set 7 | victoria
# Processing Record 42 of Set 7 | kaitangata
# Processing Record 43 of Set 7 | straumen
# Processing Record 44 of Set 7 | villarrica
# Processing Record 45 of Set 7 | kasane
# Processing Record 46 of Set 7 | natal
# Processing Record 47 of Set 7 | mount vernon
# Processing Record 48 of Set 7 | omsukchan
# Processing Record 49 of Set 7 | leo
# Processing Record 50 of Set 7 | edd
# Processing Record 1 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 8 | bow island
# Processing Record 3 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | afogados da ingazeira
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | hirara
# Processing Record 8 of Set 8 | baturaja
# Processing Record 9 of Set 8 | bandar-e lengeh
# Processing Record 10 of Set 8 | opuwo
# Processing Record 11 of Set 8 | whitehorse
# Processing Record 12 of Set 8 | helong
# Processing Record 13 of Set 8 | ugoofaaru
# Processing Record 14 of Set 8 | portland
# Processing Record 15 of Set 8 | port blair
# Processing Record 16 of Set 8 | along
# Processing Record 17 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 8 | shihezi
# Processing Record 19 of Set 8 | chama
# Processing Record 20 of Set 8 | menongue
# Processing Record 21 of Set 8 | wilhelmsburg
# Processing Record 22 of Set 8 | saint-joseph
# Processing Record 23 of Set 8 | valdivia
# Processing Record 24 of Set 8 | nicoya
# Processing Record 25 of Set 8 | rudnogorsk
# Processing Record 26 of Set 8 | tiksi
# Processing Record 27 of Set 8 | danville
# Processing Record 28 of Set 8 | mehran
# Processing Record 29 of Set 8 | jakar
# Processing Record 30 of Set 8 | westport
# Processing Record 31 of Set 8 | roald
# Processing Record 32 of Set 8 | umea
# Processing Record 33 of Set 8 | aswan
# Processing Record 34 of Set 8 | mbandaka
# Processing Record 35 of Set 8 | waingapu
# Processing Record 36 of Set 8 | kahului
# Processing Record 37 of Set 8 | estevan
# Processing Record 38 of Set 8 | manfredonia
# Processing Record 39 of Set 8 | maykor
# Processing Record 40 of Set 8 | beringovskiy
# Processing Record 41 of Set 8 | shakawe
# Processing Record 42 of Set 8 | pafos
# Processing Record 43 of Set 8 | port said
# Processing Record 44 of Set 8 | tarakan
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | abalak
# Processing Record 47 of Set 8 | kohtla-jarve
# Processing Record 48 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | iregszemcse
# Processing Record 50 of Set 8 | asau
# Processing Record 1 of Set 9 | xuddur
# Processing Record 2 of Set 9 | cabo san lucas
# Processing Record 3 of Set 9 | cabedelo
# Processing Record 4 of Set 9 | palmer
# Processing Record 5 of Set 9 | mitsamiouli
# Processing Record 6 of Set 9 | serowe
# Processing Record 7 of Set 9 | haines junction
# Processing Record 8 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 9 | inzer
# Processing Record 10 of Set 9 | flinders
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | tateyama
# Processing Record 13 of Set 9 | lom sak
# Processing Record 14 of Set 9 | cabo rojo
# Processing Record 15 of Set 9 | peniche
# Processing Record 16 of Set 9 | padang
# Processing Record 17 of Set 9 | tiznit
# Processing Record 18 of Set 9 | dakar
# Processing Record 19 of Set 9 | eyl
# Processing Record 20 of Set 9 | boende
# Processing Record 21 of Set 9 | churapcha
# Processing Record 22 of Set 9 | san jeronimo
# Processing Record 23 of Set 9 | ust-nera
# Processing Record 24 of Set 9 | sur
# Processing Record 25 of Set 9 | queenstown
# Processing Record 26 of Set 9 | coromandel
# Processing Record 27 of Set 9 | nador
# Processing Record 28 of Set 9 | elhovo
# Processing Record 29 of Set 9 | kiruna
# Processing Record 30 of Set 9 | bushehr
# Processing Record 31 of Set 9 | najran
# Processing Record 32 of Set 9 | rocha
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | chumikan
# Processing Record 35 of Set 9 | burica
# City not found. Skipping...
# Processing Record 36 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 9 | orlik
# Processing Record 38 of Set 9 | gaoua
# Processing Record 39 of Set 9 | lewistown
# Processing Record 40 of Set 9 | sao jose da coroa grande
# Processing Record 41 of Set 9 | cairns
# Processing Record 42 of Set 9 | bulungu
# Processing Record 43 of Set 9 | vestmannaeyjar
# Processing Record 44 of Set 9 | wladyslawowo
# Processing Record 45 of Set 9 | bairiki
# Processing Record 46 of Set 9 | kedrovyy
# Processing Record 47 of Set 9 | catamarca
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | chapais
# Processing Record 50 of Set 9 | soyo
# Processing Record 1 of Set 10 | arlit
# Processing Record 2 of Set 10 | pizarro
# Processing Record 3 of Set 10 | boyolangu
# Processing Record 4 of Set 10 | anloga
# Processing Record 5 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 10 | zhangye
# Processing Record 7 of Set 10 | sakakah
# Processing Record 8 of Set 10 | geraldton
# Processing Record 9 of Set 10 | asosa
# Processing Record 10 of Set 10 | igrim
# Processing Record 11 of Set 10 | xacmaz
# Processing Record 12 of Set 10 | belaya gora
# Processing Record 13 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 10 | chenzhou
# Processing Record 15 of Set 10 | srednekolymsk
# Processing Record 16 of Set 10 | port hueneme
# Processing Record 17 of Set 10 | adrar
# Processing Record 18 of Set 10 | lima
# Processing Record 19 of Set 10 | abha
# Processing Record 20 of Set 10 | ocos
# Processing Record 21 of Set 10 | evensk
# Processing Record 22 of Set 10 | zhuozhou
# City not found. Skipping...
# Processing Record 23 of Set 10 | rincon
# Processing Record 24 of Set 10 | lumeje
# Processing Record 25 of Set 10 | poso
# Processing Record 26 of Set 10 | gawler
# Processing Record 27 of Set 10 | imeni poliny osipenko
# Processing Record 28 of Set 10 | krasnyy yar
# Processing Record 29 of Set 10 | san cristobal
# Processing Record 30 of Set 10 | wickede
# Processing Record 31 of Set 10 | juliaca
# Processing Record 32 of Set 10 | voznesenskoye
# Processing Record 33 of Set 10 | atambua
# Processing Record 34 of Set 10 | ribeira grande
# Processing Record 35 of Set 10 | enshi
# Processing Record 36 of Set 10 | kakonko
# Processing Record 37 of Set 10 | saint-augustin
# Processing Record 38 of Set 10 | perelyub
# Processing Record 39 of Set 10 | constitucion
# Processing Record 40 of Set 10 | dicabisagan
# Processing Record 41 of Set 10 | mahon
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | hami
# Processing Record 44 of Set 10 | ustupo
# Processing Record 45 of Set 10 | laredo
# Processing Record 46 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 10 | rehoboth
# Processing Record 49 of Set 10 | laguna
# Processing Record 50 of Set 10 | praxedis guerrero
# Processing Record 1 of Set 11 | beyneu
# Processing Record 2 of Set 11 | mae chan
# Processing Record 3 of Set 11 | occhiobello
# Processing Record 4 of Set 11 | alta floresta
# Processing Record 5 of Set 11 | saint george
# Processing Record 6 of Set 11 | channel-port aux basques
# Processing Record 7 of Set 11 | ye
# City not found. Skipping...
# Processing Record 8 of Set 11 | mwandiga
# Processing Record 9 of Set 11 | moree
# Processing Record 10 of Set 11 | miles city
# Processing Record 11 of Set 11 | porto santo
# Processing Record 12 of Set 11 | sibu
# Processing Record 13 of Set 11 | udachnyy
# Processing Record 14 of Set 11 | brainerd
# Processing Record 15 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 16 of Set 11 | kroonstad
# Processing Record 17 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 11 | omboue
# Processing Record 19 of Set 11 | tabou
# Processing Record 20 of Set 11 | bilibino
# Processing Record 21 of Set 11 | kavieng
# Processing Record 22 of Set 11 | skjervoy
# Processing Record 23 of Set 11 | nhulunbuy
# Processing Record 24 of Set 11 | linfen
# Processing Record 25 of Set 11 | maceio
# Processing Record 26 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | novopskov
# Processing Record 28 of Set 11 | kamaishi
# Processing Record 29 of Set 11 | pacific grove
# Processing Record 30 of Set 11 | besancon
# Processing Record 31 of Set 11 | barraute
# Processing Record 32 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 11 | viterbo
# Processing Record 34 of Set 11 | houston
# Processing Record 35 of Set 11 | syracuse
# Processing Record 36 of Set 11 | sola
# Processing Record 37 of Set 11 | dargaville
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | ixtapa
# Processing Record 40 of Set 11 | the valley
# Processing Record 41 of Set 11 | meulaboh
# Processing Record 42 of Set 11 | kishanganj
# Processing Record 43 of Set 11 | oranjemund
# Processing Record 44 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 11 | hamilton
# Processing Record 46 of Set 11 | katangli
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | lorengau
# Processing Record 49 of Set 11 | arrifes
# Processing Record 50 of Set 11 | gladstone
# Processing Record 1 of Set 12 | baghdad
# Processing Record 2 of Set 12 | lavumisa
# Processing Record 3 of Set 12 | vanavara
# Processing Record 4 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 12 | galveston
# Processing Record 7 of Set 12 | kyzyl-suu
# Processing Record 8 of Set 12 | cozmesti
# Processing Record 9 of Set 12 | katherine
# Processing Record 10 of Set 12 | den helder
# Processing Record 11 of Set 12 | chipinge
# Processing Record 12 of Set 12 | kismayo
# Processing Record 13 of Set 12 | paka
# Processing Record 14 of Set 12 | kyaikkami
# Processing Record 15 of Set 12 | fukue
# Processing Record 16 of Set 12 | ibra
# Processing Record 17 of Set 12 | te anau
# Processing Record 18 of Set 12 | sinazongwe
# Processing Record 19 of Set 12 | belmonte
# Processing Record 20 of Set 12 | morant bay
# Processing Record 21 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 12 | nikki
# Processing Record 23 of Set 12 | plettenberg bay
# Processing Record 24 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 12 | loikaw
# Processing Record 26 of Set 12 | hovd
# Processing Record 27 of Set 12 | vao
# Processing Record 28 of Set 12 | ringebu
# Processing Record 29 of Set 12 | jega
# Processing Record 30 of Set 12 | mount isa
# Processing Record 31 of Set 12 | kuytun
# Processing Record 32 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 12 | jubayl
# City not found. Skipping...
# Processing Record 34 of Set 12 | deniliquin
# Processing Record 35 of Set 12 | bukama
# Processing Record 36 of Set 12 | karatau
# Processing Record 37 of Set 12 | porto de moz
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | naklo nad notecia
# Processing Record 40 of Set 12 | janakkala
# Processing Record 41 of Set 12 | arenapolis
# Processing Record 42 of Set 12 | magdagachi
# Processing Record 43 of Set 12 | darhan
# Processing Record 44 of Set 12 | finnsnes
# Processing Record 45 of Set 12 | minab
# Processing Record 46 of Set 12 | rio grande
# Processing Record 47 of Set 12 | port hardy
# Processing Record 48 of Set 12 | kichera
# Processing Record 49 of Set 12 | iquitos
# Processing Record 50 of Set 12 | la ronge
# Processing Record 1 of Set 13 | bathsheba
# Processing Record 2 of Set 13 | ranong
# Processing Record 3 of Set 13 | zabol
# Processing Record 4 of Set 13 | sungairaya
# Processing Record 5 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 13 | calmar
# Processing Record 8 of Set 13 | asfi
# Processing Record 9 of Set 13 | cairo
# Processing Record 10 of Set 13 | okoneshnikovo
# Processing Record 11 of Set 13 | fortuna
# Processing Record 12 of Set 13 | la palma
# Processing Record 13 of Set 13 | ostrovnoy
# Processing Record 14 of Set 13 | manta
# Processing Record 15 of Set 13 | dengzhou
# Processing Record 16 of Set 13 | allapalli
# Processing Record 17 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 18 of Set 13 | sinjai
# Processing Record 19 of Set 13 | avera
# Processing Record 20 of Set 13 | igarka
# Processing Record 21 of Set 13 | buenos aires
# Processing Record 22 of Set 13 | uvat
# Processing Record 23 of Set 13 | srandakan
# Processing Record 24 of Set 13 | quchan
# Processing Record 25 of Set 13 | dukat
# Processing Record 26 of Set 13 | battle creek
# Processing Record 27 of Set 13 | lasa
# Processing Record 28 of Set 13 | panaba
# Processing Record 29 of Set 13 | nizhniy kuranakh
# Processing Record 30 of Set 13 | banda aceh
# Processing Record 31 of Set 13 | kaduqli
# Processing Record 32 of Set 13 | zlitan
# Processing Record 33 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 13 | prince rupert
# Processing Record 35 of Set 13 | kabin buri
# Processing Record 36 of Set 13 | molina
# Processing Record 37 of Set 13 | luanda
# Processing Record 38 of Set 13 | phaltan
# Processing Record 39 of Set 13 | atasu
# Processing Record 40 of Set 13 | abnub
# Processing Record 41 of Set 13 | pedro carbo
# Processing Record 42 of Set 13 | san antonio
# Processing Record 43 of Set 13 | taksimo
# Processing Record 44 of Set 13 | shache
# Processing Record 45 of Set 13 | bangolo
# Processing Record 46 of Set 13 | nouadhibou
# Processing Record 47 of Set 13 | sao miguel do araguaia
# Processing Record 48 of Set 13 | peace river
# Processing Record 49 of Set 13 | corleone
# Processing Record 50 of Set 13 | kalabo
# Processing Record 1 of Set 14 | strezhevoy
# Processing Record 2 of Set 14 | gat
# Processing Record 3 of Set 14 | jardanhaza
# Processing Record 4 of Set 14 | jalu
# Processing Record 5 of Set 14 | boa vista
# Processing Record 6 of Set 14 | sangar
# Processing Record 7 of Set 14 | paamiut
# Processing Record 8 of Set 14 | usogorsk
# Processing Record 9 of Set 14 | kuryk
# Processing Record 10 of Set 14 | dhamtari
# Processing Record 11 of Set 14 | livadiya
# Processing Record 12 of Set 14 | pak phanang
# Processing Record 13 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 14 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 15 of Set 14 | joshimath
# Processing Record 16 of Set 14 | snyder
# Processing Record 17 of Set 14 | guadalupe
# Processing Record 18 of Set 14 | whyalla
# Processing Record 19 of Set 14 | makat
# Processing Record 20 of Set 14 | masuguru
# Processing Record 21 of Set 14 | alice springs
# Processing Record 22 of Set 14 | smoky lake
# Processing Record 23 of Set 14 | ketchikan
# Processing Record 24 of Set 14 | bowen
# Processing Record 25 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 14 | causwagan
# Processing Record 27 of Set 14 | kieta
# Processing Record 28 of Set 14 | karatsu
# Processing Record 29 of Set 14 | punta alta
# Processing Record 30 of Set 14 | mackenzie
# Processing Record 31 of Set 14 | kashi
# Processing Record 32 of Set 14 | byron bay
# Processing Record 33 of Set 14 | buala
# Processing Record 34 of Set 14 | leshan
# Processing Record 35 of Set 14 | kirakira
# Processing Record 36 of Set 14 | coahuayana
# Processing Record 37 of Set 14 | ambilobe
# Processing Record 38 of Set 14 | kemin
# Processing Record 39 of Set 14 | mana
# Processing Record 40 of Set 14 | ulaangom
# Processing Record 41 of Set 14 | montepuez
# Processing Record 42 of Set 14 | burnie
# Processing Record 43 of Set 14 | oxapampa
# Processing Record 44 of Set 14 | gravdal
# Processing Record 45 of Set 14 | araouane
# Processing Record 46 of Set 14 | manokwari
# Processing Record 47 of Set 14 | svetlyy
# Processing Record 48 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 14 | calvinia
# Processing Record 50 of Set 14 | tatawin
# Processing Record 1 of Set 15 | meaford
# Processing Record 2 of Set 15 | manono
# Processing Record 3 of Set 15 | kavaratti
# Processing Record 4 of Set 15 | novikovo
# Processing Record 5 of Set 15 | kewanee
# Processing Record 6 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 15 | aitape
# Processing Record 8 of Set 15 | iisalmi
# Processing Record 9 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 15 | amet
# Processing Record 11 of Set 15 | sobolevo
# Processing Record 12 of Set 15 | goderich
# Processing Record 13 of Set 15 | iskateley
# Processing Record 14 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 15 | bemidji
# Processing Record 16 of Set 15 | bella vista
# Processing Record 17 of Set 15 | bitkine
# Processing Record 18 of Set 15 | samfya
# Processing Record 19 of Set 15 | sri aman
# Processing Record 20 of Set 15 | charyshskoye
# Processing Record 21 of Set 15 | kropotkin
# Processing Record 22 of Set 15 | maniitsoq
# Processing Record 23 of Set 15 | manggar
# Processing Record 24 of Set 15 | litovko
# Processing Record 25 of Set 15 | linden
# Processing Record 26 of Set 15 | taraz
# Processing Record 27 of Set 15 | tucurui
# Processing Record 28 of Set 15 | abu zabad
# Processing Record 29 of Set 15 | zhanaozen
# Processing Record 30 of Set 15 | severobaykalsk
# Processing Record 31 of Set 15 | necochea
# Processing Record 32 of Set 15 | thinadhoo
# Processing Record 33 of Set 15 | daigo
# Processing Record 34 of Set 15 | visnes
# Processing Record 35 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 36 of Set 15 | yulara
# Processing Record 37 of Set 15 | itainopolis
# Processing Record 38 of Set 15 | aripuana
# Processing Record 39 of Set 15 | hare bay
# Processing Record 40 of Set 15 | hit
# Processing Record 41 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 15 | hobyo
# Processing Record 43 of Set 15 | shiloh
# Processing Record 44 of Set 15 | hellvik
# Processing Record 45 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 46 of Set 15 | oum hadjer
# Processing Record 47 of Set 15 | yamada
# Processing Record 48 of Set 15 | siquijor
# Processing Record 49 of Set 15 | glendive
# Processing Record 50 of Set 15 | nizwa
# Processing Record 1 of Set 16 | rawson
# Processing Record 2 of Set 16 | fort-shevchenko
# Processing Record 3 of Set 16 | blackfoot
# Processing Record 4 of Set 16 | liseleje
# Processing Record 5 of Set 16 | prachuap khiri khan
# Processing Record 6 of Set 16 | morgan city
# Processing Record 7 of Set 16 | tomakomai
# Processing Record 8 of Set 16 | tynda
# Processing Record 9 of Set 16 | umm bab
# Processing Record 10 of Set 16 | cartagena del chaira
# Processing Record 11 of Set 16 | tahta
# Processing Record 12 of Set 16 | wanning
# Processing Record 13 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 14 of Set 16 | jasper
# Processing Record 15 of Set 16 | carutapera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    New Norfolk -42.7826  147.0587     51.01        85          97
# 1        Ushuaia -54.8000  -68.3000     42.80        87          75
# 2         Nemuro  43.3236  145.5750     38.66        84         100
# 3         Atuona  -9.8000 -139.0333     80.11        80          28
# 4    Yerbogachen  61.2767  108.0108     27.82        87          95
# 5        Merauke  -8.4667  140.3333     77.47        88          74
# 6  Narasannapeta  18.4167   84.0500     79.41        84          98
# 7     Bredasdorp -34.5322   20.0403     50.00        93          99
# 8        Lampang  18.3333   99.5000     87.01        67          36
# 9      Ilulissat  69.2167  -51.1000     35.60        69         100
#
#    Wind Speed Country                 Date
# 0        1.01      AU  2021-04-23 20:42:26
# 1        2.30      AR  2021-04-23 20:39:45
# 2       14.34      JP  2021-04-23 20:42:26
# 3       22.08      PF  2021-04-23 20:41:47
# 4        6.49      RU  2021-04-23 20:42:26
# 5        5.64      ID  2021-04-23 20:42:27
# 6        2.62      IN  2021-04-23 20:42:27
# 7        4.61      ZA  2021-04-23 20:42:27
# 8        2.75      TH  2021-04-23 20:42:28
# 9        3.44      GL  2021-04-23 20:42:28

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
